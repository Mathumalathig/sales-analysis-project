# %% [markdown]
# ## 1. Introduction
#
# This project involves analyzing sales data for AAL, a renowned clothing brand in Australia. AAL has a widespread presence across various states and caters to all age groups, from kids to the elderly. The data represents sales for the **fourth quarter of 2020**.
#
# ### Objective of the Analysis
#
# The primary objective of this analysis is to help the Sales and Marketing (S&M) team of AAL make informed, data-driven decisions. This will assist in:
# - Identifying top-performing states and demographic groups.
# - Strategizing sales programs for states with lower performance.
# - Understanding buying behavior patterns based on time of day.
# - Analyzing weekly and monthly sales trends.
# - Generating meaningful visual insights using Python libraries.
#
# Ultimately, this analysis supports AAL’s expansion initiatives and helps optimize their marketing strategies.

# %% [markdown]
# ## 2. Data Wrangling
#
# In this phase, we loaded the dataset and performed essential data cleaning and formatting tasks to prepare it for analysis.
#
# ### Steps Involved:
#
# - **Loading the dataset** into a Pandas DataFrame.
# - **Inspecting basic information** such as data types, null values, and data ranges using `.info()` and `.head()`.
# - **Datetime parsing**: Converted the `Time` column to a datetime format to support time-based analysis.
# - **Feature extraction**:
#   - Extracted **hour** from `Time` to analyze time-of-day trends.
#   - Created `Time_Converted` column to group times into 'Morning', 'Afternoon', and 'Evening' for better clarity.
# - Verified data consistency and confirmed that there were no missing or invalid values.
#
# These preprocessing steps ensured the data was clean and well-structured for further analysis and isualization.

# %%
import pandas as pd

# %%
sa = pd.read_csv("AusApparalSales4thQrt2020.csv")

# %%
sa.head() # Display first few rows
# Out:
#          Date        Time State     Group  Unit  Sales
# 0  1-Oct-2020     Morning    WA      Kids     8  20000
# 1  1-Oct-2020     Morning    WA       Men     8  20000
# 2  1-Oct-2020     Morning    WA     Women     4  10000
# 3  1-Oct-2020     Morning    WA   Seniors    15  37500
# 4  1-Oct-2020   Afternoon    WA      Kids     3   7500

# %%
sa.info() # Display datatypes, null checks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   object
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 354.5+ KB

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
#
# This phase focuses on analyzing sales trends and uncovering meaningful insights from the data using visualizations.

# %% [markdown]
# ### 3.1 State-wise Sales Analysis
#
# We analyzed sales performance across different states and customer groups.
#
# - Grouped data by `State` and `Group` to calculate total sales.
# - Visualized the results using a grouped bar chart to compare age-group performance in each state.
#
# **Insight:** States like VIC and NSW showed higher sales across all groups, while NT and WA recorded comparatively lower figures.

# %%
from IPython.display import Image
Image("state_wise_sales_analysis.png") # Include grouped sales by state barplot

# %% [markdown]
# ### 3.2 Group-wise Performance
#
# We examined which customer groups contributed the most to sales.
#
# - Grouped data by `Group` and calculated:
#   - Total `Sales`
#   - Total `Units` purchased
# - Visualized both sales and unit contribution using bar charts.
#
# **Insight:** The **Women** and **Men** segments consistently contributed more in terms of both units and sales, followed by **Kids** and **Seniors**.

# %%
Image("Group_wise_sales.png")

# %% [markdown]
# ### 3.3 Time-of-Day Sales Trend
#
# We studied how sales vary across different parts of the day.
#
# - Grouped data based on `Time_Converted` (Morning, Afternoon, Evening).
# - Summed total sales for each period.
# - Used a line plot to visualize sales trends over time of day.
#
# **Insight:** Most purchases occurred during the **Morning**, indicating a strong preference for early-day shopping.

# %%
Image("Sales_Trend_over_timeoftheday.png")

# %% [markdown]
# ## Peak Purchase Time
#
# We identified the exact hour with the highest total sales.
#
# - Peak Purchase Time: 09:00
# - Total Sales: 114,207,500
#
# **Insight:** **09:00 AM** had the highest sales volume, marking it as the peak purchase time.

# %% [markdown]
# ### 3.4 Weekly and Monthly Trends
#
# We analyzed how sales changed over weeks and months.
#
# - Extracted `Week` and `Month` from the datetime index.
# - Grouped and summed sales accordingly.
# - Plotted sales trends to observe fluctuations and peaks.
#
# **Insight:** Sales remained consistent throughout the quarter with slight increases during mid-October and early December.

# %%
Image("weekly_sales_trend.png")

# %%
Image("Montly_sales_trend.png")

# %% [markdown]
# ## 4. Correlation Analysis
#
# The goal of this section is to understand how numerical features in the dataset relate to each other.
#
# We used a heatmap to visualize the correlation between numerical variables such as:
# - `Unit`
# - `Sale
#
# Insight:
# A strong positive correlation (~1.0) was found between Unit and Sales, indicating that more units sold directly translates to more revenue.
#
# This is expected, but it validates that our data is consistent and reliable for sales behavior modeling.s`

# %%
sa[['Unit','Sales']].corr()
# Out:
#        Unit  Sales
# Unit    1.0    1.0
# Sales   1.0    1.0

# %%
Image("Correlation_Matrix.png")

# %% [markdown]
# ## 5. Conclusion and Recommendations
#
# ### 🧾 Conclusion:
#
# This sales analysis provided useful insights into customer buying behavior over a 3-month period. Here's a summary of key findings:
#
# - **NSW and VIC** are the top-performing states in terms of overall sales.
# - **Women** and **Men** groups contribute the most to the revenue across all states.
# - The **most active purchase time** is around **09:00 AM**, indicating a strong morning shopping trend.
# - Weekly and monthly trends show **consistent sales throughout the quarter**, with slight peaks in mid-months.
# - There is a **strong positive correlation** between the number of units sold and the total sales revenue — validating the data quality.
#
# ### 📌 Recommendations:
#
# - **Boost promotions around 9:00 AM** to capitalize on peak purchase time.
# - **Focus on high-performing states** (like NSW and VIC) for targeted marketing and inventory strategies.
# - Introduce **age-group specific campaigns**, especially for the Women and Men segments.
# - Ensure high-demand products are stocked adequately during peak times and high-performing weeks.
#
# This analysis can serve as a foundation for more advanced predictive modeling or decision support systems in future projects.
